# %% [markdown]
# ## Import libraries

# %%
from dotenv import load_dotenv
from google.cloud import storage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_google_vertexai import VertexAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone
import fitz
import os

# %%
# Import environment variables from .env file
load_dotenv()

PROJECT_ID = os.getenv("GOOGLE_CLOUD_PROJECT")
GCS_BUCKET = os.getenv("GCS_BUCKET")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_ENVIRONMENT = os.getenv("PINECONE_ENVIRONMENT")

# %% [markdown]
# ## Pull data from GCS

# %%
"""Function to convert pdf bytes to text"""
def get_data_from_pdf(pdf_bytes):
    text = ""
    with fitz.open(stream=pdf_bytes, filename="pdf") as doc:
        for page in doc:
            text += page.get_text()
    return text

# %%
"""Function that reads all documents from GCS bucket"""
def read_all_docs():  
    client = storage.Client(project=PROJECT_ID)
    bucket = client.bucket(GCS_BUCKET)
    prefix = "raw_data/"
    blobs = bucket.list_blobs(prefix=prefix)

    contents = {}

    for blob in blobs:
        if blob.name.endswith("/"):
            continue

        content = ""

        if blob.name.lower().endswith(".pdf"):
            pdf_bytes = blob.download_as_bytes()
            content = get_data_from_pdf(pdf_bytes)
        else:
            content = blob.download_as_text()
        
        contents[blob.name] = content

    return contents

# %%
# Trigger data extraction
contents = read_all_docs()
print("Import complete!")
# Out:
# MuPDF error: format error: cmsOpenProfileFromMem failed
#
# MuPDF error: format error: cmsOpenProfileFromMem failed
#
# MuPDF error: format error: cmsOpenProfileFromMem failed
#
# MuPDF error: format error: No default Layer config
#
# MuPDF error: format error: No default Layer config
#
# MuPDF error: format error: No default Layer config
#
# Import complete!

# %% [markdown]
# ## Chunk and embed data

# %%
"""Function to chunk text data"""
def chunk_documents_batch(documents, chunk_size=1000, chunk_overlap=200):
    # Iterate through douments and create lanchain document with content and filename
    lc_documents = [Document(page_content=doc_content, metadata={"source": doc_name}) 
                    for doc_name, doc_content in documents.items()
    ]

    # Initialise RecursiveCharacterTextSplitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, 
        chunk_overlap=chunk_overlap, 
        separators=["\n\n", "\n", ".", " "], 
        length_function=len
    )

    # Split langchain documents into chunks
    split_docs = text_splitter.split_documents(lc_documents)

    return split_docs

# %%
"""Function to embed documents"""
def embed_and_upload_to_pinecone(documents, batch_size=100):

    if not all([PINECONE_API_KEY, PINECONE_ENVIRONMENT, PINECONE_INDEX_NAME]):
        raise EnvironmentError("Missing Pinecone credentials in .env file.")

    # Initialize Pinecone and fetch the index
    pc = Pinecone(api_key=PINECONE_API_KEY, environment=PINECONE_ENVIRONMENT)
    index = pc.Index(PINECONE_INDEX_NAME)

    # Use Vertex AI embedding model
    embedding_model = VertexAIEmbeddings(model_name="text-embedding-005")

    # Initialise vectorstore
    vector_store = PineconeVectorStore(index=index, embedding=embedding_model)

    # Batch upload vectors to Pinecone
    for i in range(0, len(documents), batch_size):
        batch = documents[i:i + batch_size]
        vector_store.add_documents(batch)
        print(f"Uploaded batch {i//batch_size + 1} of {len(documents)//batch_size + 1}")

    print(f"Uploaded {len(documents)} documents to Pinecone index '{PINECONE_INDEX_NAME}'")

# %%
# Trigger chunking
split_docs = chunk_documents_batch(contents)
print(f"{len(split_docs)} chunks were created!")

# Trigger upload to Pinecone
embed_and_upload_to_pinecone(split_docs)
# Out:
# 28859 chunks were created!
# Uploaded batch 1 of 289
# Uploaded batch 2 of 289
# Uploaded batch 3 of 289
# Uploaded batch 4 of 289
# Uploaded batch 5 of 289
# Uploaded batch 6 of 289
# Uploaded batch 7 of 289
# Uploaded batch 8 of 289
# Uploaded batch 9 of 289
# Uploaded batch 10 of 289
# Uploaded batch 11 of 289
# Uploaded batch 12 of 289
# Uploaded batch 13 of 289
# Uploaded batch 14 of 289
# Uploaded batch 15 of 289
# Uploaded batch 16 of 289
# Uploaded batch 17 of 289
# Uploaded batch 18 of 289
# Uploaded batch 19 of 289
# Uploaded batch 20 of 289
# Uploaded batch 21 of 289
# Uploaded batch 22 of 289
# Uploaded batch 23 of 289
# Uploaded batch 24 of 289
# Uploaded batch 25 of 289
# Uploaded batch 26 of 289
# Uploaded batch 27 of 289
# Uploaded batch 28 of 289
# Uploaded batch 29 of 289
# Uploaded batch 30 of 289
# Uploaded batch 31 of 289
# Uploaded batch 32 of 289
# Uploaded batch 33 of 289
# Uploaded batch 34 of 289
# Uploaded batch 35 of 289
# Uploaded batch 36 of 289
# Uploaded batch 37 of 289
# Uploaded batch 38 of 289
# Uploaded batch 39 of 289
# Uploaded batch 40 of 289
# Uploaded batch 41 of 289
# Uploaded batch 42 of 289
# Uploaded batch 43 of 289
# Uploaded batch 44 of 289
# Uploaded batch 45 of 289
# Uploaded batch 46 of 289
# Uploaded batch 47 of 289
# Uploaded batch 48 of 289
# Uploaded batch 49 of 289
# Uploaded batch 50 of 289
# Uploaded batch 51 of 289
# Uploaded batch 52 of 289
# Uploaded batch 53 of 289
# Uploaded batch 54 of 289
# Uploaded batch 55 of 289
# Uploaded batch 56 of 289
# Uploaded batch 57 of 289
# Uploaded batch 58 of 289
# Uploaded batch 59 of 289
# Uploaded batch 60 of 289
# Uploaded batch 61 of 289
# Uploaded batch 62 of 289
# Uploaded batch 63 of 289
# Uploaded batch 64 of 289
# Uploaded batch 65 of 289
# Uploaded batch 66 of 289
# Uploaded batch 67 of 289
# Uploaded batch 68 of 289
# Uploaded batch 69 of 289
# Uploaded batch 70 of 289
# Uploaded batch 71 of 289
# Uploaded batch 72 of 289
# Uploaded batch 73 of 289
# Uploaded batch 74 of 289
# Uploaded batch 75 of 289
# Uploaded batch 76 of 289
# Uploaded batch 77 of 289
# Uploaded batch 78 of 289
# Uploaded batch 79 of 289
# Uploaded batch 80 of 289
# Uploaded batch 81 of 289
# Uploaded batch 82 of 289
# Uploaded batch 83 of 289
# Uploaded batch 84 of 289
# Uploaded batch 85 of 289
# Uploaded batch 86 of 289
# Uploaded batch 87 of 289
# Uploaded batch 88 of 289
# Uploaded batch 89 of 289
# Uploaded batch 90 of 289
# Uploaded batch 91 of 289
# Uploaded batch 92 of 289
# Uploaded batch 93 of 289
# Uploaded batch 94 of 289
# Uploaded batch 95 of 289
# Uploaded batch 96 of 289
# Uploaded batch 97 of 289
# Uploaded batch 98 of 289
# Uploaded batch 99 of 289
# Uploaded batch 100 of 289
# Uploaded batch 101 of 289
# Uploaded batch 102 of 289
# Uploaded batch 103 of 289
# Uploaded batch 104 of 289
# Uploaded batch 105 of 289
# Uploaded batch 106 of 289
# Uploaded batch 107 of 289
# Uploaded batch 108 of 289
# Uploaded batch 109 of 289
# Uploaded batch 110 of 289
# Uploaded batch 111 of 289
# Uploaded batch 112 of 289
# Uploaded batch 113 of 289
# Uploaded batch 114 of 289
# Uploaded batch 115 of 289
# Uploaded batch 116 of 289
# Uploaded batch 117 of 289
# Uploaded batch 118 of 289
# Uploaded batch 119 of 289
# Uploaded batch 120 of 289
# Uploaded batch 121 of 289
# Uploaded batch 122 of 289
# Uploaded batch 123 of 289
# Uploaded batch 124 of 289
# Uploaded batch 125 of 289
# Uploaded batch 126 of 289
# Uploaded batch 127 of 289
# Uploaded batch 128 of 289
# Uploaded batch 129 of 289
# Uploaded batch 130 of 289
# Uploaded batch 131 of 289
# Uploaded batch 132 of 289
# Uploaded batch 133 of 289
# Uploaded batch 134 of 289
# Uploaded batch 135 of 289
# Uploaded batch 136 of 289
# Uploaded batch 137 of 289
# Uploaded batch 138 of 289
# Uploaded batch 139 of 289
# Uploaded batch 140 of 289
# Uploaded batch 141 of 289
# Uploaded batch 142 of 289
# Uploaded batch 143 of 289
# Uploaded batch 144 of 289
# Uploaded batch 145 of 289
# Uploaded batch 146 of 289
# Uploaded batch 147 of 289
# Uploaded batch 148 of 289
# Uploaded batch 149 of 289
# Uploaded batch 150 of 289
# Uploaded batch 151 of 289
# Uploaded batch 152 of 289
# Uploaded batch 153 of 289
# Uploaded batch 154 of 289
# Uploaded batch 155 of 289
# Uploaded batch 156 of 289
# Uploaded batch 157 of 289
# Uploaded batch 158 of 289
# Uploaded batch 159 of 289
# Uploaded batch 160 of 289
# Uploaded batch 161 of 289
# Uploaded batch 162 of 289
# Uploaded batch 163 of 289
# Uploaded batch 164 of 289
# Uploaded batch 165 of 289
# Uploaded batch 166 of 289
# Uploaded batch 167 of 289
# Uploaded batch 168 of 289
# Uploaded batch 169 of 289
# Uploaded batch 170 of 289
# Uploaded batch 171 of 289
# Uploaded batch 172 of 289
# Uploaded batch 173 of 289
# Uploaded batch 174 of 289
# Uploaded batch 175 of 289
# Uploaded batch 176 of 289
# Uploaded batch 177 of 289
# Uploaded batch 178 of 289
# Uploaded batch 179 of 289
# Uploaded batch 180 of 289
# Uploaded batch 181 of 289
# Uploaded batch 182 of 289
# Uploaded batch 183 of 289
# Uploaded batch 184 of 289
# Uploaded batch 185 of 289
# Uploaded batch 186 of 289
# Uploaded batch 187 of 289
# Uploaded batch 188 of 289
# Uploaded batch 189 of 289
# Uploaded batch 190 of 289
# Uploaded batch 191 of 289
# Uploaded batch 192 of 289
# Uploaded batch 193 of 289
# Uploaded batch 194 of 289
# Uploaded batch 195 of 289
# Uploaded batch 196 of 289
# Uploaded batch 197 of 289
# Uploaded batch 198 of 289
# Uploaded batch 199 of 289
# Uploaded batch 200 of 289
# Uploaded batch 201 of 289
# Uploaded batch 202 of 289
# Uploaded batch 203 of 289
# Uploaded batch 204 of 289
# Uploaded batch 205 of 289
# Uploaded batch 206 of 289
# Uploaded batch 207 of 289
# Uploaded batch 208 of 289
# Uploaded batch 209 of 289
# Uploaded batch 210 of 289
# Uploaded batch 211 of 289
# Uploaded batch 212 of 289
# Uploaded batch 213 of 289
# Uploaded batch 214 of 289
# Uploaded batch 215 of 289
# Uploaded batch 216 of 289
# Uploaded batch 217 of 289
# Uploaded batch 218 of 289
# Uploaded batch 219 of 289
# Uploaded batch 220 of 289
# Uploaded batch 221 of 289
# Uploaded batch 222 of 289
# Uploaded batch 223 of 289
# Uploaded batch 224 of 289
# Uploaded batch 225 of 289
# Uploaded batch 226 of 289
# Uploaded batch 227 of 289
# Uploaded batch 228 of 289
# Uploaded batch 229 of 289
# Uploaded batch 230 of 289
# Uploaded batch 231 of 289
# Uploaded batch 232 of 289
# Uploaded batch 233 of 289
# Uploaded batch 234 of 289
# Uploaded batch 235 of 289
# Uploaded batch 236 of 289
# Uploaded batch 237 of 289
# Uploaded batch 238 of 289
# Uploaded batch 239 of 289
# Uploaded batch 240 of 289
# Uploaded batch 241 of 289
# Uploaded batch 242 of 289
# Uploaded batch 243 of 289
# Uploaded batch 244 of 289
# Uploaded batch 245 of 289
# Uploaded batch 246 of 289
# Uploaded batch 247 of 289
# Uploaded batch 248 of 289
# Uploaded batch 249 of 289
# Uploaded batch 250 of 289
# Uploaded batch 251 of 289
# Uploaded batch 252 of 289
# Uploaded batch 253 of 289
# Uploaded batch 254 of 289
# Uploaded batch 255 of 289
# Uploaded batch 256 of 289
# Uploaded batch 257 of 289
# Uploaded batch 258 of 289
# Uploaded batch 259 of 289
# Uploaded batch 260 of 289
# Uploaded batch 261 of 289
# Uploaded batch 262 of 289
# Uploaded batch 263 of 289
# Uploaded batch 264 of 289
# Uploaded batch 265 of 289
# Uploaded batch 266 of 289
# Uploaded batch 267 of 289
# Uploaded batch 268 of 289
# Uploaded batch 269 of 289
# Uploaded batch 270 of 289
# Uploaded batch 271 of 289
# Uploaded batch 272 of 289
# Uploaded batch 273 of 289
# Uploaded batch 274 of 289
# Uploaded batch 275 of 289
# Uploaded batch 276 of 289
# Uploaded batch 277 of 289
# Uploaded batch 278 of 289
# Uploaded batch 279 of 289
# Uploaded batch 280 of 289
# Uploaded batch 281 of 289
# Uploaded batch 282 of 289
# Uploaded batch 283 of 289
# Uploaded batch 284 of 289
# Uploaded batch 285 of 289
# Uploaded batch 286 of 289
# Uploaded batch 287 of 289
# Uploaded batch 288 of 289
# Uploaded batch 289 of 289
# Uploaded 28859 documents to Pinecone index 'smart-qna-index'
